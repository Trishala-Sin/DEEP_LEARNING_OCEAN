# %% [markdown]
# # Deep Learning Playlist
# ### Discussion
#
# Deep learning terms and topics
#
# - Understand what they mean
# - How they fit in to the overall deep learning framework
# - How certain topics are implemented in code
# - Using Keras

# %% [markdown]
# ## Machine Learning (ML)

# %% [markdown]
# Machine Learning is the practice of using algorithms to analyze data, learn from that data, and then make a determination or prediction about new data.

# %% [markdown]
# ### Machine Learning vs. Traditional Programming

# %% [markdown]
# Example: Analyzing the sentiment of a popular media outlet and classifying that sentiment as positive or negative
#
# - Traditional programming approach
#  - The algorithm may first look for particular words associated with a negative or positive sentiment.
#  - With conditional statements, the algorithm would classify articles as positive or negative based on the words that it knows are positive or negative.
#
# - Machine learning approach
#  - The algorithm would analyze large amounts of given media data and *learn* the features that classify what a negative article looks like versus a positive article.
#  - With what it's learned, the algorithm could then classify new articles as positive or negative.

# %% [markdown]
# ## Deep Learning (DL)

# %% [markdown]
# We'll start by covering the most basic idea about what deep learning is and how it’s used. Later,  we’ll be cover more detailed concepts, terms, and tools within the field of deep learning.
#
# **Definition:**
#
# - Deep learning is a subfield of machine learning that uses algorithms inspired by the structure and function of the brain’s neural networks.
# - As a subfield of machine learning (ML), deep learning (DL) also uses algorithms to analyze data, learn from that data, and then make a determination or prediction about new data.

# %% [markdown]
# **Supervised learning** occurs when your deep learning model learns and makes inferences from data that has already been *labeled*.
#
# **Unsupervised learning** occurs when the model learns and makes inferences from *unlabeled* data.

# %% [markdown]
# **Labeled vs. Unlabeled example**
#
# - Classify images of cats and dogs

# %% [markdown]
# ### Artificial Neural Networks

# %% [markdown]
# Artificial neural networks are deep learning models that are based on the structure of the brain's neural networks.
#
# - Artificial neural networks are used interchangeably with the terms
#   - neural net
#   - net
#   - model

# %% [markdown]
# ## Artificial Neural Networks (ANNs)

# %% [markdown]
# Artificial neural networks are computing systems that are inspired by the brain’s neural networks.
#
# - These networks are based on a collection of connected units called **artificial neurons**, or **neurons**.
# - Each connection between neurons can transmit a signal from one neuron to another.
# - The receiving neuron processes the signal and signals downstream neurons connected to it.
# - Neurons are organized in layers.
#  - Input layer
#  - Hidden layers
#  - Output layer

# %% [markdown]
# ### Keras Sequential Model

# %% [markdown]
# The Sequential model is a linear stack of layers.

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation

model = Sequential([
    Dense(units=32, input_shape=(10,), activation='relu'),
    Dense(units=2, activation='softmax'),
])
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Layers in an ANN

# %% [markdown]
# Artificial neural network are typically organized in layers.
# Different types of layers include
#
# - Dense (or fully connected) Layers
# - Convolutional layers
# - Pooling Layers
# - Recurrent Layers
# - Normalization Layers
# - Many others

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation

model = Sequential([
    Dense(units=5, input_shape=(3,), activation='relu'),
    Dense(units=2, activation='softmax'),
])

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

img = np.expand_dims(plt.imread('resources/NN.PNG'),0)
plt.imshow(img[0])

# %% [markdown]
# ## Activation Functions

# %% [markdown]
# In an artificial neural network, the activation function of a neuron defines the output of that neuron given a set of inputs.
#
# - Biologically inspired by activity in our brains, where different neurons fire, or are *activated*, by different stimuli.

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation

model = Sequential([
    Dense(units=5, input_shape=(3,), activation='relu')
])

# %%
model = Sequential()
model.add(Dense(units=5, input_shape=(3,)))
model.add(Activation('relu'))

# %% [markdown]
# ### Pre-process data for training

# %%
import numpy as np
from random import randint
from sklearn.preprocessing import MinMaxScaler

# %%
train_labels =  []
train_samples = []

# %% [markdown]
# Example data:
# - An experimental drug was tested on individuals from ages 13 to 100.
# - The trial had 2100 participants. Half were under 65 years old, half were over 65 years old.
# - 95% of patients 65 or older experienced side effects.
# - 95% of patients under 65 experienced no side effects.

# %%
for i in range(50):
    # The 5% of younger individuals who did experience side effects
    random_younger = randint(13,64)
    train_samples.append(random_younger)
    train_labels.append(1)
    
    # The 5% of older individuals who did not experience side effects
    random_older = randint(65,100)
    train_samples.append(random_older)
    train_labels.append(0)

for i in range(1000):
    # The 95% of younger individuals who did not experience side effects
    random_younger = randint(13,64)
    train_samples.append(random_younger)
    train_labels.append(0)
    
    # The 95% of older individuals who did experience side effects
    random_older = randint(65,100)
    train_samples.append(random_older)
    train_labels.append(1)

# %%
train_labels = np.array(train_labels)
train_samples = np.array(train_samples)

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_train_samples = scaler.fit_transform(train_samples.reshape(-1,1))

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

img = np.expand_dims(plt.imread('resources/NN.PNG'),0)
plt.imshow(img[0])

# %% [markdown]
# ## Training

# %% [markdown]
# Solving an optimization problem
#  - Optimizing weights
#   - with Stochastic Gradient Descent (SGD)
#  - Objective: Minimize the loss function

# %% [markdown]
# ## Learning

# %%
import keras
from keras.models import Sequential
from keras.layers import Activation
from keras.layers.core import Dense
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy

# %%
model = Sequential([
    Dense(units=16, input_shape=(1,), activation='relu'),
    Dense(units=32, activation='relu'),
    Dense(units=2, activation='sigmoid')
])

# %%
model.compile(optimizer=Adam(learning_rate=0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x=scaled_train_samples, y=train_labels, batch_size=10, epochs=20, shuffle=True, verbose=2)
# Out:
# Epoch 1/20
#  - 0s - loss: 0.6541 - accuracy: 0.5467
# Epoch 2/20
#  - 0s - loss: 0.6302 - accuracy: 0.6157
# Epoch 3/20
#  - 0s - loss: 0.6020 - accuracy: 0.6952
# Epoch 4/20
#  - 0s - loss: 0.5759 - accuracy: 0.7267
# Epoch 5/20
#  - 0s - loss: 0.5483 - accuracy: 0.7638
# Epoch 6/20
#  - 0s - loss: 0.5192 - accuracy: 0.8029
# Epoch 7/20
#  - 0s - loss: 0.4871 - accuracy: 0.8333
# Epoch 8/20
#  - 0s - loss: 0.4544 - accuracy: 0.8624
# Epoch 9/20
#  - 0s - loss: 0.4228 - accuracy: 0.8805
# Epoch 10/20
#  - 0s - loss: 0.3937 - accuracy: 0.8952
# Epoch 11/20
#  - 0s - loss: 0.3678 - accuracy: 0.9048
# Epoch 12/20
#  - 0s - loss: 0.3455 - accuracy: 0.9119
# Epoch 13/20
#  - 0s - loss: 0.3272 - accuracy: 0.9200
# Epoch 14/20
#  - 0s - loss: 0.3119 - accuracy: 0.9252
# Epoch 15/20
#  - 0s - loss: 0.2997 - accuracy: 0.9300
# Epoch 16/20
#  - 0s - loss: 0.2903 - accuracy: 0.9338
# Epoch 17/20
#  - 0s - loss: 0.2820 - accuracy: 0.9343
# Epoch 18/20
#  - 0s - loss: 0.2761 - accuracy: 0.9329
# Epoch 19/20
#  - 0s - loss: 0.2706 - accuracy: 0.9324
# Epoch 20/20
#  - 0s - loss: 0.2665 - accuracy: 0.9386

# %% [markdown]
# ## Data Sets

# %%
scaled_train_samples
# Out:
# array([[0.43678161],
#        [0.95402299],
#        [0.54022989],
#        ...,
#        [0.79310345],
#        [0.50574713],
#        [0.97701149]])

# %%
train_labels
# Out:
# array([1, 0, 1, ..., 1, 0, 1])

# %%
model.fit(x=scaled_train_samples, y=train_labels, validation_split = 0.20, batch_size=10, 
          epochs=20, shuffle=True, verbose=2)
# Out:
# Train on 1680 samples, validate on 420 samples
# Epoch 1/20
#  - 0s - loss: 0.2927 - accuracy: 0.9250 - val_loss: 0.1447 - val_accuracy: 0.9833
# Epoch 2/20
#  - 0s - loss: 0.2910 - accuracy: 0.9262 - val_loss: 0.1420 - val_accuracy: 0.9833
# Epoch 3/20
#  - 0s - loss: 0.2894 - accuracy: 0.9262 - val_loss: 0.1393 - val_accuracy: 0.9833
# Epoch 4/20
#  - 0s - loss: 0.2883 - accuracy: 0.9280 - val_loss: 0.1376 - val_accuracy: 0.9881
# Epoch 5/20
#  - 0s - loss: 0.2868 - accuracy: 0.9286 - val_loss: 0.1350 - val_accuracy: 0.9833
# Epoch 6/20
#  - 0s - loss: 0.2856 - accuracy: 0.9262 - val_loss: 0.1331 - val_accuracy: 0.9881
# Epoch 7/20
#  - 0s - loss: 0.2846 - accuracy: 0.9274 - val_loss: 0.1316 - val_accuracy: 0.9881
# Epoch 8/20
#  - 0s - loss: 0.2840 - accuracy: 0.9315 - val_loss: 0.1293 - val_accuracy: 0.9833
# Epoch 9/20
#  - 0s - loss: 0.2826 - accuracy: 0.9262 - val_loss: 0.1280 - val_accuracy: 0.9833
# Epoch 10/20
#  - 0s - loss: 0.2819 - accuracy: 0.9292 - val_loss: 0.1266 - val_accuracy: 0.9833
# Epoch 11/20
#  - 0s - loss: 0.2811 - accuracy: 0.9268 - val_loss: 0.1254 - val_accuracy: 0.9881
# Epoch 12/20
#  - 0s - loss: 0.2805 - accuracy: 0.9315 - val_loss: 0.1240 - val_accuracy: 0.9833
# Epoch 13/20
#  - 0s - loss: 0.2799 - accuracy: 0.9262 - val_loss: 0.1228 - val_accuracy: 0.9833
# Epoch 14/20
#  - 0s - loss: 0.2795 - accuracy: 0.9292 - val_loss: 0.1214 - val_accuracy: 0.9833
# Epoch 15/20
#  - 0s - loss: 0.2784 - accuracy: 0.9268 - val_loss: 0.1211 - val_accuracy: 0.9881
# Epoch 16/20
#  - 0s - loss: 0.2781 - accuracy: 0.9304 - val_loss: 0.1197 - val_accuracy: 0.9881
# Epoch 17/20
#  - 0s - loss: 0.2775 - accuracy: 0.9292 - val_loss: 0.1188 - val_accuracy: 0.9881
# Epoch 18/20
#  - 0s - loss: 0.2768 - accuracy: 0.9268 - val_loss: 0.1181 - val_accuracy: 0.9881
# Epoch 19/20
#  - 0s - loss: 0.2765 - accuracy: 0.9304 - val_loss: 0.1173 - val_accuracy: 0.9881
# Epoch 20/20
#  - 0s - loss: 0.2761 - accuracy: 0.9286 - val_loss: 0.1164 - val_accuracy: 0.9881

# %% [markdown]
# ### Validation set format for training

# %%
# valid_set = [(sample, label), (sample, label), ... , (sample, label)]

# %%
# model.fit(x=scaled_train_samples, y=train_labels, validation_data = valid_set, batch_size=10, 
#           epochs=20, shuffle=True, verbose=2)

# %% [markdown]
# ## Regularization

# %%
import keras
from keras.models import Sequential
from keras.layers import Activation
from keras.layers.core import Dense
from keras.optimizers import Adam
from keras import regularizers

# %%
model = Sequential([
    Dense(units=16, input_shape=(1,), activation='relu'),
    Dense(units=32, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dense(units=2, activation='sigmoid')
])

# %% [markdown]
# ## Learning Rate

# %%
model.compile(optimizer=Adam(learning_rate=0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.optimizer.learning_rate = 0.01

# %%
model.optimizer.learning_rate
# Out:
# 0.01

# %% [markdown]
# ## Predicting

# %%
import keras
from keras.models import Sequential
from keras.layers import Activation
from keras.layers.core import Dense
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy

# %%
model = Sequential([
    Dense(units=16, input_shape=(1,), activation='relu'),
    Dense(units=32, activation='relu'),
    Dense(units=2, activation='sigmoid')
])

# %%
model.compile(optimizer=Adam(learning_rate=0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x=scaled_train_samples, y=train_labels, batch_size=10, epochs=20, shuffle=True, verbose=2)
# Out:
# Epoch 1/20
#  - 0s - loss: 0.6885 - accuracy: 0.5681
# Epoch 2/20
#  - 0s - loss: 0.6760 - accuracy: 0.7624
# Epoch 3/20
#  - 0s - loss: 0.6621 - accuracy: 0.8429
# Epoch 4/20
#  - 0s - loss: 0.6469 - accuracy: 0.8533
# Epoch 5/20
#  - 0s - loss: 0.6278 - accuracy: 0.8790
# Epoch 6/20
#  - 0s - loss: 0.6075 - accuracy: 0.8733
# Epoch 7/20
#  - 0s - loss: 0.5853 - accuracy: 0.8786
# Epoch 8/20
#  - 0s - loss: 0.5618 - accuracy: 0.8838
# Epoch 9/20
#  - 0s - loss: 0.5374 - accuracy: 0.8871
# Epoch 10/20
#  - 0s - loss: 0.5123 - accuracy: 0.8881
# Epoch 11/20
#  - 0s - loss: 0.4874 - accuracy: 0.8881
# Epoch 12/20
#  - 0s - loss: 0.4630 - accuracy: 0.9005
# Epoch 13/20
#  - 0s - loss: 0.4382 - accuracy: 0.9029
# Epoch 14/20
#  - 0s - loss: 0.4141 - accuracy: 0.9057
# Epoch 15/20
#  - 0s - loss: 0.3923 - accuracy: 0.9081
# Epoch 16/20
#  - 0s - loss: 0.3727 - accuracy: 0.9124
# Epoch 17/20
#  - 0s - loss: 0.3553 - accuracy: 0.9148
# Epoch 18/20
#  - 0s - loss: 0.3403 - accuracy: 0.9190
# Epoch 19/20
#  - 0s - loss: 0.3273 - accuracy: 0.9190
# Epoch 20/20
#  - 0s - loss: 0.3160 - accuracy: 0.9233

# %% [markdown]
# ### Preprocess test data

# %%
test_labels =  []
test_samples = []

for i in range(10):
    # The 5% of younger individuals who did experience side effects
    random_younger = randint(13,64)
    test_samples.append(random_younger)
    test_labels.append(1)
    
    # The 5% of older individuals who did not experience side effects
    random_older = randint(65,100)
    test_samples.append(random_older)
    test_labels.append(0)

for i in range(200):
    # The 95% of younger individuals who did not experience side effects
    random_younger = randint(13,64)
    test_samples.append(random_younger)
    test_labels.append(0)
    
    # The 95% of older individuals who did experience side effects
    random_older = randint(65,100)
    test_samples.append(random_older)
    test_labels.append(1)
    
test_labels = np.array(test_labels)
test_samples = np.array(test_samples)

scaler = MinMaxScaler(feature_range=(0,1))
scaled_test_samples = scaler.fit_transform(test_samples.reshape(-1,1))

# %%
predictions = model.predict(x=scaled_test_samples, batch_size=10, verbose=0)

# %%
for i in predictions:
    print(i)
# Out:
# [0.80274546 0.08380153]
# [0.06083037 0.6768714 ]
# [0.80440646 0.08238517]
# [0.08352131 0.6284943 ]
# [0.79426813 0.08449972]
# [0.15446608 0.49769738]
# [0.80341524 0.08131103]
# [0.11467369 0.5633198 ]
# [0.8039922  0.08273721]
# [0.20487134 0.43215424]
# [0.48520386 0.21686547]
# [0.15446608 0.49769738]
# [0.5022586  0.20796192]
# [0.06295881 0.6723943 ]
# [0.80274546 0.08380153]
# [0.08043522 0.6356364 ]
# [0.7997948  0.08254901]
# [0.06742549 0.6633459 ]
# [0.51930815 0.19933084]
# [0.07754803 0.64211273]
# [0.5700318  0.17506257]
# [0.06515653 0.66788554]
# [0.46818337 0.22604148]
# [0.05484242 0.6901074 ]
# [0.5700318  0.17506257]
# [0.18337145 0.4582165 ]
# [0.6959051  0.12174771]
# [0.0973988  0.59827876]
# [0.80520684 0.08069842]
# [0.06742549 0.6633459 ]
# [0.80564535 0.08133725]
# [0.06742549 0.6633459 ]
# [0.7239913  0.11081555]
# [0.08352131 0.6284943 ]
# [0.80698615 0.08009003]
# [0.06742549 0.6633459 ]
# [0.80482006 0.0820345 ]
# [0.22807308 0.40632907]
# [0.7997948  0.08254901]
# [0.10794953 0.576142  ]
# [0.7739315  0.09197012]
# [0.06976755 0.65877575]
# [0.8064679  0.08064537]
# [0.0973988  0.59827876]
# [0.80440646 0.08238517]
# [0.15446608 0.49769738]
# [0.80520684 0.08069843]
# [0.06976755 0.65877575]
# [0.80482006 0.0820345 ]
# [0.25298584 0.3809267 ]
# [0.48520386 0.21686547]
# [0.18337145 0.4582165 ]
# [0.4012199  0.26543853]
# [0.18337145 0.4582165 ]
# [0.45123672 0.23548898]
# [0.25298584 0.3809267 ]
# [0.417718   0.25519058]
# [0.12184308 0.55029804]
# [0.3849426  0.27594557]
# [0.09001807 0.6140432 ]
# [0.4012199  0.26543853]
# [0.06742549 0.6633459 ]
# [0.79426813 0.08449972]
# [0.06083037 0.6768714 ]
# [0.51930815 0.19933084]
# [0.06976755 0.65877575]
# [0.7739315  0.09197012]
# [0.15446608 0.49769738]
# [0.635278   0.14640583]
# [0.15446608 0.49769738]
# [0.80440646 0.08238517]
# [0.09001807 0.6140432 ]
# [0.7842735  0.08816347]
# [0.18337145 0.4582165 ]
# [0.6662784  0.13359632]
# [0.22807308 0.40632907]
# [0.43440238 0.24520619]
# [0.06295881 0.6723943 ]
# [0.417718   0.25519058]
# [0.12939514 0.537207  ]
# [0.76297444 0.09603137]
# [0.07484382 0.6479599 ]
# [0.43440238 0.24520619]
# [0.07222652 0.6537631 ]
# [0.8064679  0.08064537]
# [0.06976755 0.65877575]
# [0.32266146 0.3204393 ]
# [0.05484242 0.6901074 ]
# [0.5022586  0.20796192]
# [0.09001807 0.6140432 ]
# [0.79426813 0.08449972]
# [0.06295881 0.6723943 ]
# [0.33775142 0.30896103]
# [0.06742549 0.6633459 ]
# [0.29358393 0.34404972]
# [0.05297491 0.69436204]
# [0.36891884 0.28670612]
# [0.1732961  0.47134313]
# [0.7997948  0.08254901]
# [0.05876938 0.6813163 ]
# [0.43440238 0.24520619]
# [0.25298584 0.3809267 ]
# [0.58667034 0.16750816]
# [0.20487134 0.43215424]
# [0.80564535 0.08133725]
# [0.20487134 0.43215424]
# [0.805233   0.08168518]
# [0.20487134 0.43215424]
# [0.7374164  0.10567839]
# [0.11467369 0.5633198 ]
# [0.46818337 0.22604148]
# [0.12939514 0.53720707]
# [0.5532336  0.18288286]
# [0.10794953 0.576142  ]
# [0.45123672 0.23548898]
# [0.13734217 0.5240645 ]
# [0.7739315  0.09197012]
# [0.05876938 0.6813163 ]
# [0.80564535 0.08133725]
# [0.13734217 0.5240645 ]
# [0.33775142 0.30896103]
# [0.05876938 0.6813163 ]
# [0.80341524 0.08131103]
# [0.08671464 0.62129563]
# [0.8016112  0.08192791]
# [0.06976755 0.65877575]
# [0.80274546 0.08380153]
# [0.12939514 0.53720707]
# [0.36891884 0.28670612]
# [0.12184308 0.55029804]
# [0.46818337 0.22604148]
# [0.05297491 0.69436204]
# [0.635278   0.14640583]
# [0.11467369 0.5633198 ]

# %% [markdown]
# ## Supervised Learning

# %%
import keras
from keras.models import Sequential
from keras.layers import Activation
from keras.layers.core import Dense
from keras.optimizers import Adam
import numpy as np

# %%
model = Sequential([
    Dense(units=16, input_shape=(2,), activation='relu'),
    Dense(units=32, activation='relu'),
    Dense(units=2, activation='sigmoid')
])

# %%
model.compile(optimizer=Adam(learning_rate=0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# weight, height
train_samples = np.array([[150, 67], [130, 60], [200, 65], [125, 52], [230, 72], [181, 70]])

# %%
# 0: male
# 1: female
train_labels = [1, 1, 0, 1, 0, 0]

# %%
model.fit(x=train_samples, y=train_labels, batch_size=3, epochs=10, shuffle=True, verbose=2)
# Out:
# Epoch 1/10
#  - 0s - loss: 0.6931 - accuracy: 0.8333
# Epoch 2/10
#  - 0s - loss: 0.6931 - accuracy: 0.8333
# Epoch 3/10
#  - 0s - loss: 0.6931 - accuracy: 0.8333
# Epoch 4/10
#  - 0s - loss: 0.6931 - accuracy: 0.8333
# Epoch 5/10
#  - 0s - loss: 0.6931 - accuracy: 0.8333
# Epoch 6/10
#  - 0s - loss: 0.6931 - accuracy: 0.8333
# Epoch 7/10
#  - 0s - loss: 0.6931 - accuracy: 0.8333
# Epoch 8/10
#  - 0s - loss: 0.6931 - accuracy: 0.8333
# Epoch 9/10
#  - 0s - loss: 0.6931 - accuracy: 0.8333
# Epoch 10/10
#  - 0s - loss: 0.6931 - accuracy: 0.8333

# %% [markdown]
# ## Batch Normalization

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization

# %%
model = Sequential([
    Dense(units=16, input_shape=(1,5), activation='relu'),
    Dense(units=32, activation='relu'),
    BatchNormalization(axis=1),
    Dense(units=2, activation='softmax')
])

# %%
#beta_initializer: Initializer for the beta weight.
#gamma_initializer: Initializer for the gamma weight.
